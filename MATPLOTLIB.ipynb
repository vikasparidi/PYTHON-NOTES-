# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#5th line is to get graphs inside jupyter

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2012-07-18',periods = 1000),columns=['data'])

#date_format : 'yyyy-mm-dd'

# %%
df
# Out:
#                 data
# 2012-07-18  0.588131
# 2012-07-19  0.897714
# 2012-07-20  0.891531
# 2012-07-21  0.815837
# 2012-07-22  0.035890
# ...              ...
# 2015-04-09  0.992189
# 2015-04-10  0.756037
# 2015-04-11  0.299186
# 2015-04-12  0.261712
# 2015-04-13  0.968979
#
# [1000 rows x 1 columns]

# %%
#By looking at the data we cannot get any idea what actually this dataset looks like

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ON X-AXIS INDEX(DATES) ARE PRESENT.
#
# ON Y-AXIS VALUES ARE PRESENT

# %%
df.data.cumsum()
# Out:
# 2012-07-18      0.588131
# 2012-07-19      1.485845
# 2012-07-20      2.377375
# 2012-07-21      3.193213
# 2012-07-22      3.229102
#                  ...
# 2015-04-09    495.812936
# 2015-04-10    496.568973
# 2015-04-11    496.868159
# 2015-04-12    497.129872
# 2015-04-13    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda x : x*3)

# %%
df
# Out:
#                 data       data1     data2
# 2012-07-18  0.588131    0.588131  1.764392
# 2012-07-19  0.897714    1.485845  2.693141
# 2012-07-20  0.891531    2.377375  2.674592
# 2012-07-21  0.815837    3.193213  2.447512
# 2012-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2015-04-09  0.992189  495.812936  2.976566
# 2015-04-10  0.756037  496.568973  2.268112
# 2015-04-11  0.299186  496.868159  0.897559
# 2015-04-12  0.261712  497.129872  0.785137
# 2015-04-13  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (10,10))

#INCREASING THE SIZE OF FIGURE
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')

#inside sns we have so many data

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
#what ever the numerical value it is plotting.

# %%
gf = df1.plot(figsize = (10,10), title="irish data")

# %%
gf.set_xlabel("this is x axes")
# Out:
# Text(0.5, 3.200000000000003, 'this is x axes')

# %%
gf
# Out:
# <AxesSubplot:title={'center':'irish data'}, xlabel='this is x axes'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot()
# Out:
# <AxesSubplot:>

# %%
df1.iloc[0][0:4].plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# LOADING OF TITANIC DATA USING SEABORN

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.534850  0.141536  0.997549  0.663146
# 1  0.310007  0.127744  0.547494  0.029529
# 2  0.344711  0.929877  0.579118  0.643341
# 3  0.557322  0.307009  0.887460  0.760641
# 4  0.249756  0.648684  0.123295  0.508399
# 5  0.174770  0.759351  0.493705  0.254648
# 6  0.393292  0.008692  0.296240  0.232336
# 7  0.841515  0.442961  0.656447  0.080341
# 8  0.719348  0.575515  0.577130  0.251678
# 9  0.166954  0.675000  0.177515  0.724717

# %%
df3.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()

#HISTROGRAPH 

#IN THIS X AXIS = RANGE
# Y AXIS = FREQUENCY
#we can also be able to draw normal distribution curve 

#this graphs says that how much data been available between some range 

#THIS MAINLY TELLS ABOUT DISTRIBUTION OF DATA
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(kind = 'hist' , stacked = True, bins=100,figsize =(10,10))

#bins:width of the graph
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(kind = 'hist' , figsize = (10,10), stacked = True, bins =100 ,title="histogram of iris")
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, ylabel='Frequency'>

# %%
#orientation in horizontal

# %%
df1.plot(kind = 'hist' , figsize = (10,10), stacked = True, bins =100 ,title="histogram of iris",orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, xlabel='Frequency'>

# %%
#seperate graphs for each data

# %%
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
#also able to change the colour
#alpha helps in increase or decrease of the contrast

# %%
df1.hist(figsize = (10,10),color = "r",alpha = .9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
#scatter plot

# %%
df1.plot.scatter(x='sepal_length', y ='petal_width')

#giving out the relation between 2 kind of data inside a same dataframe
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',c='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
#colour is been determined by the value of petal_length
#based on the value the contrast of the colour changes
#If we want to know the dependency of third value on another 2 values we can use this kind of method

# %% [markdown]
# #

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
#giving of naames to dots

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label = 'vikas')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label = 'vikas',s=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label = 'vikas',s=10,c='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x='sepal_length',y='sepal_width',label='sudh',gridsize = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                 data       data1     data2
# 2012-07-18  0.588131    0.588131  1.764392
# 2012-07-19  0.897714    1.485845  2.693141
# 2012-07-20  0.891531    2.377375  2.674592
# 2012-07-21  0.815837    3.193213  2.447512
# 2012-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2015-04-09  0.992189  495.812936  2.976566
# 2015-04-10  0.756037  496.568973  2.268112
# 2015-04-11  0.299186  496.868159  0.897559
# 2015-04-12  0.261712  497.129872  0.785137
# 2015-04-13  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d
# Out:
# data     0.588131
# data1    0.588131
# data2    1.764392
# Name: 2012-07-18 00:00:00, dtype: float64

# %%
d.plot()
# Out:
# <AxesSubplot:>

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2012-07-18 00:00:00'>

# %%
#pie graph shows the percentage contribution

# %%
d.plot.pie(figsize = (10,10))
# Out:
# <AxesSubplot:ylabel='2012-07-18 00:00:00'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.head(3).T
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5       3     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris = df1.head(3).T

# %%
iris
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5       3     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris .iloc[0:4].plot.pie(subplots = True, figsize = (20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris .iloc[0:4].plot.pie(subplots = True, figsize = (20,20),fontsize = 10 ,autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df1 , figsize=(10,10))


#we are getting all to all relation ship
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
#we can find histographs in the diagonal

# %%
#we can change the diagonal graphs

# %%
pd.plotting.scatter_matrix(df1 , figsize=(10,10),diagonal = 'kde')

#kde = kernel density estimation
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df
# Out:
#                 data       data1     data2
# 2012-07-18  0.588131    0.588131  1.764392
# 2012-07-19  0.897714    1.485845  2.693141
# 2012-07-20  0.891531    2.377375  2.674592
# 2012-07-21  0.815837    3.193213  2.447512
# 2012-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2015-04-09  0.992189  495.812936  2.976566
# 2015-04-10  0.756037  496.568973  2.268112
# 2015-04-11  0.299186  496.868159  0.897559
# 2015-04-12  0.261712  497.129872  0.785137
# 2015-04-13  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df['data'].plot(style = 'r--' , legend = True , label = 'my_name')
# Out:
# <AxesSubplot:>

# %%
df['data'].plot(style = 'r*' , legend = True , label = 'my_name')
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68727 sha256=5291267c1f9bf7bf46a6f46f214db7afacf655de058d03b20e38b2eac8f8c88c
#   Stored in directory: c:\users\91951\appdata\local\pip\cache\wheels\6b\76\62\6da97734911ffcbdd559fd1a3f28526321f0ae699182a23866
# Successfully built cufflinks
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '4.14.3'

# %%
py.offline.init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iplot()
# Out:
# <div>                            <div id="7f4d8f24-70ce-44e4-a2c5-3c4811ba7b63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['survived'].plot.pie()
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
df2.iplot( x = 'fare', y = 'age' , kind = 'scatter' , mode = 'markers' , xTitle = 'fare', yTitle = 'age')
# Out:
# <div>                            <div id="569b17ab-7841-410b-8861-1a075dce7717" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}
